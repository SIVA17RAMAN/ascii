# %%
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import make_blobs

# %%
n_sample1=1000
n_sample2=100

# %%
centers=[[0.0,0.0],[2.0,2.0]]
clusters_std=[1.5,0.5]

# %%
x,y=make_blobs(n_samples=[n_sample1,n_sample2],centers=centers,cluster_std=clusters_std,random_state=0,shuffle=False,)

# %%
print(x)
# Out:
# [[ 2.64607852  0.60023581]
#  [ 1.46810698  3.3613398 ]
#  [ 2.80133699 -1.46591682]
#  ...
#  [ 1.68550965  2.53503626]
#  [ 1.68945865  2.86728609]
#  [ 1.45085528  2.28630668]]

# %%
print(y)
# Out:
# [0 0 0 ... 1 1 1]

# %%
clf=svm.SVC(kernel="linear",C=1.0)
clf.fit(x,y)
# Out:
# SVC(kernel='linear')

# %%
wclf=svm.SVC(kernel="linear",class_weight={1:10})
wclf.fit(x,y)
# Out:
# SVC(class_weight={1: 10}, kernel='linear')

# %%
plt.scatter(x[:,0],x[:,1],c=y,cmap=plt.cm.Paired,edgecolors="k")
